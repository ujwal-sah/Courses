# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Ujwal Raj Sah**
# Civil Engineer

# %% [markdown]
# *I am interested in data science because it can help me prepare a background in the field of Intelligent Transportation System.*

# %% [markdown]
# ### The following is a common code used as first program in many tutorials

# %%
x = "Hello World"
print(x)
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20200321132842-0000
# KERNEL_ID = f9850368-255f-4d60-8d04-f4837b77f587
# Hello World

# %% [markdown]
# Shopping List for 21st March, 2020
# ---
# * AA Size Batteries
# * ~~Sharpner~~
# * Pencil
# * Eraser
#
# Class Position and Names
# ---
# |Name|Position|
# |---|---:|
# |Ujwal|1|
# |Raj|2|
# |sah|3|
